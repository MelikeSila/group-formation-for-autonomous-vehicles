# %%
import os
import matplotlib.pyplot as plt
from IPython import display
from brute_force import calculate_score
import commonroad.planning
# import functions to read xml file and visualize commonroad objects
from commonroad.common.file_reader import CommonRoadFileReader
from commonroad.visualization.draw_dispatch_cr import draw_object

# generate path of the file to be opened
#file_path = "C-USA_US101-30_1_T-1.xml"
file_path = "DEU_A9-1_1_T-1.xml"
#file_path = "CHN_Sha-4_1_T-1.xml"
#file_path = "CHN_Cho-2_1_T-1.xml"

# read in the scenario and planning problem set
crf = CommonRoadFileReader(file_path)
scenario, planning_problem_set = crf.open()


# plot the scenario for 40 time step, here each time step corresponds to 0.1 second
for i in range(0, 10):
    # uncomment to clear previous graph
    display.clear_output(wait=True)
    
    plt.figure(figsize=(20, 10))
    # plot the scenario at different time step
    draw_object(scenario, draw_params={'dynamic_obstacle':{'show_label':True}})
    # plot the planning problem set
    draw_object(planning_problem_set)
    plt.gca().set_aspect('equal')
    plt.show()

# %%
print(list(planning_problem_set.planning_problem_dict.values()))

# %%
w_size, w_vel, w_dist= 1, 1, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[200], [201, 202, 205], [203], [204]]

# %%
w_size, w_vel, w_dist= 5, 10, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[200, 203], [201, 202, 205], [204]]

# %%
w_size, w_vel, w_dist= 100, 1, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[200, 203], [201, 202], [204, 205]]

# %%
w_size, w_vel, w_dist= 2, 2, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[200], [201, 202, 205], [203], [204]]

# %%
# different scenario
file_path = "USA_Peach-4_3_T-1.xml"


# read in the scenario and planning problem set
crf = CommonRoadFileReader(file_path)
scenario, planning_problem_set = crf.open()


# plot the scenario for 40 time step, here each time step corresponds to 0.1 second
for i in range(0, 10):
    # uncomment to clear previous graph
    display.clear_output(wait=True)
    
    plt.figure(figsize=(20, 10))
    # plot the scenario at different time step
    draw_object(scenario, draw_params={'dynamic_obstacle':{'show_label':True}})
    # plot the planning problem set
    draw_object(planning_problem_set)
    plt.gca().set_aspect('equal')
    plt.show()

# %%
w_size, w_vel, w_dist= 1, 1, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[11], [17], [53], [98], [102, 104]]

# %%
w_size, w_vel, w_dist= 5, 10, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[11, 17], [53], [98, 102, 104]]

# %%
w_size, w_vel, w_dist= 100, 1, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[11, 17], [53, 102], [98, 104]]

# %%
w_size, w_vel, w_dist= 2, 2, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[11, 17], [53], [98], [102, 104]]

# %%
# different scenario
file_path = "DEU_Muc-7_1_T-1.xml"


# read in the scenario and planning problem set
crf = CommonRoadFileReader(file_path)
scenario, planning_problem_set = crf.open()


# plot the scenario for 40 time step, here each time step corresponds to 0.1 second
for i in range(0, 10):
    # uncomment to clear previous graph
    display.clear_output(wait=True)
    
    plt.figure(figsize=(20, 10))
    # plot the scenario at different time step
    draw_object(scenario, draw_params={'dynamic_obstacle':{'show_label':True}})
    # plot the planning problem set
    draw_object(planning_problem_set)
    plt.gca().set_aspect('equal')
    plt.show()

# %%
w_size, w_vel, w_dist= 1, 1, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[30], [36, 38], [37, 41, 42], [39, 40]]

# %%
w_size, w_vel, w_dist= 5, 10, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[30, 37, 41, 42], [36, 38, 39, 40]]

# %%
w_size, w_vel, w_dist= 100, 1, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[30, 37], [36, 38], [39, 40], [41, 42]]

# %%
w_size, w_vel, w_dist= 2, 2, 1
groups, scores=calculate_score.get_assignments_scores(scenario, planning_problem_set, 2, w_size, w_vel, w_dist)
best_groups=calculate_score.get_best_assignment(groups,scores)
print (best_groups)
# Out:
# [[30], [36, 38], [37, 41, 42], [39, 40]]
