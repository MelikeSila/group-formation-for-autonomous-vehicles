# %%
from GraphBasedDistanceMeasure import ScenarioGraph
from commonroad.common.file_reader import CommonRoadFileReader
import networkx as nx
import matplotlib.pyplot as plt

# generate path of the file to be opened
#file_path = "data_files/ZAM_Tutorial-1_1_T-1.xml"
#file_path2 = "data_files/ZAM_Tjunction-1_66_T-1.xml"
file_path = "data_files/CHN_Cho-2_1_T-1.xml"
file_path2 = "data_files/DEU_A9-1_1_T-1.xml"

# read in the scenario and planning problem set
crf = CommonRoadFileReader(file_path)
scenario, planning_problem_set = crf.open()

crf2 = CommonRoadFileReader(file_path2)
scenario2, planning_problem_set2 = crf2.open()

#for graph attributes
options1 = {
    'node_color': 'lightgreen',
    'node_size': 1000,
    'width': 1,
}

options2 = {
    'node_color': 'green',
    'node_size': 500,
    'width': 1,
}

plt.rcParams['figure.figsize'] = (20.0, 20.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

#################################BRIEF USAGE###############################################
###########################################################################################
#############################GBDM Sample Usage ############################################
###########################################################################################
#Creata an ScenariGraph object
SG_1 = ScenarioGraph(scenario, planning_problem_set)
SG_2 = ScenarioGraph(scenario2, planning_problem_set2)
#SG_1.CreateLaneletGraph()  #you dont need to create graph. It created in constructer method

plt.subplot(1, 2, 1)
nx.draw(SG_1.scenario_graph,with_labels=True, font_weight='bold', **options1)
plt.subplot(1, 2, 2)
nx.draw(SG_2.scenario_graph,with_labels=True, font_weight='bold', **options2)
plt.show()
# Out:
# /home/melike/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/melike/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
##################################################################
######         Sample Usage of Vehicle Object               ######
##################################################################


from Vehicle import Vehicle
from Sensor  import DistanceSensor

#take information from ScenarioGraph
cars = { **SG_1.ego_vehicles_dic, **SG_1.obstacles_dic}
car_ids = SG_1.obstacle_ids + SG_1.ego_vehicle_ids

#dict to collect vehicle objects in the scenario and planning problem set
vehicle_object_dict = dict()

#creating vehicle object for each vehicle in the scenario and planning problem set
for car in cars:
    vehicle_object_dict[car] = Vehicle(cars[car], SG_1, sensor_range = 0.1)

# now we created one Vehicle object for each vehicle and obstacle in the xml data
# and store the each object in the vehicle_object_dict dictionary

#usage of vehicle object's attributes
for vehicle_object_id in vehicle_object_dict:
    print("vehicle id : ", vehicle_object_id)
    print("group_array: ", vehicle_object_dict[vehicle_object_id].group_array)
    print("score_array: ", vehicle_object_dict[vehicle_object_id].score_array)
    print()
# Out:
# vehicle id :  -1
# group_array:  None
# score_array:  None
#
# vehicle id :  35
# group_array:  None
# score_array:  None
#
# vehicle id :  39
# group_array:  None
# score_array:  None
#
# vehicle id :  311
# group_array:  None
# score_array:  None
#
# vehicle id :  313
# group_array:  None
# score_array:  None
#
# vehicle id :  315
# group_array:  None
# score_array:  None
#
# vehicle id :  317
# group_array:  None
# score_array:  None
#
# vehicle id :  318
# group_array:  None
# score_array:  None
#
# vehicle id :  319
# group_array:  None
# score_array:  None
#
# vehicle id :  320
# group_array:  None
# score_array:  None
#
# vehicle id :  321
# group_array:  None
# score_array:  None
#
# vehicle id :  322
# group_array:  None
# score_array:  None
#
# vehicle id :  323
# group_array:  None
# score_array:  None
#
# vehicle id :  324
# group_array:  None
# score_array:  None
#
# vehicle id :  326
# group_array:  None
# score_array:  None
#
# vehicle id :  327
# group_array:  None
# score_array:  None
#
# vehicle id :  328
# group_array:  None
# score_array:  None
#
# vehicle id :  329
# group_array:  None
# score_array:  None
#
# vehicle id :  330
# group_array:  None
# score_array:  None
#
# vehicle id :  331
# group_array:  None
# score_array:  None
