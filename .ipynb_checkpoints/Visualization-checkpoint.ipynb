# %%
from GraphBasedDistanceMeasure import ScenarioGraph
from commonroad.common.file_reader import CommonRoadFileReader
import networkx as nx
import matplotlib.pyplot as plt

# generate path of the file to be opened
#file_path = "data_files/ZAM_Tutorial-1_1_T-1.xml"
#file_path2 = "data_files/ZAM_Tjunction-1_66_T-1.xml"
file_path = "data_files/CHN_Cho-2_1_T-1.xml"
file_path2 = "data_files/DEU_A9-1_1_T-1.xml"

# read in the scenario and planning problem set
crf = CommonRoadFileReader(file_path)
scenario, planning_problem_set = crf.open()

crf2 = CommonRoadFileReader(file_path2)
scenario2, planning_problem_set2 = crf2.open()

#for graph attributes
options1 = {
    'node_color': 'lightgreen',
    'node_size': 1000,
    'width': 1,
}

options2 = {
    'node_color': 'green',
    'node_size': 500,
    'width': 1,
}

plt.rcParams['figure.figsize'] = (20.0, 20.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

#################################BRIEF USAGE###############################################
###########################################################################################
#############################GBDM Sample Usage ############################################
###########################################################################################
#Creata an ScenariGraph object
SG_1 = ScenarioGraph(scenario, planning_problem_set)
SG_2 = ScenarioGraph(scenario2, planning_problem_set2)
#SG_1.CreateLaneletGraph()  #you dont need to create graph. It created in constructer method

plt.subplot(1, 2, 1)
nx.draw(SG_1.scenario_graph,with_labels=True, font_weight='bold', **options1)
plt.subplot(1, 2, 2)
nx.draw(SG_2.scenario_graph,with_labels=True, font_weight='bold', **options2)
plt.show()
# Out:
# /home/melike/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/melike/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
vehicle_objects = SG_1.vehicle_objects_dict

for vehicle_dict_id in vehicle_objects:
    print("vehicle object:  ", vehicle_objects[vehicle_dict_id])
    print("vehicle_info:    ", vehicle_objects[vehicle_dict_id].vehicle_info)
    
    #Initial_state usage
    print("**vehicle_info.initial_state:    ", (vehicle_objects[vehicle_dict_id].vehicle_info["initial_state"]))
    print("vehicle_initial_state:    ", vehicle_objects[vehicle_dict_id].vehicle_initial_state)
    print("vehicle_initial_state.velocity:    ", vehicle_objects[vehicle_dict_id].vehicle_initial_state.velocity)
    print("vehicle_initial_state.position:    ", vehicle_objects[vehicle_dict_id].vehicle_initial_state.position)
    
    
    print("vehicle_graph:   ", vehicle_objects[vehicle_dict_id].vehicle_graph)
    print("distance_sensor: ", vehicle_objects[vehicle_dict_id].distance_sensor)
    print("distance_sensor.vehicles_in_range: ", vehicle_objects[vehicle_dict_id].distance_sensor.vehicles_in_range)
    print("score_array:     ", vehicle_objects[vehicle_dict_id].score_dict)
    print("group_array:     ", vehicle_objects[vehicle_dict_id].group_array)
    print("knowledge_base:  ", vehicle_objects[vehicle_dict_id].knowledge_base)
    
    print("___________________________________________________________________________________________________")
# Out:
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4abe0b610>
# vehicle_info:     {'id': -1, 'initial_position': array([ 67.348 , 377.2854]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a96bbb90>, 'initial_lanelet_id': 59, 'initial_lanelet_node': 0, 'planning_problem_id': 1}
# **vehicle_info.initial_state:
# position= [ 67.348  377.2854]
# orientation= -2.4137
# velocity= 22.699
# yaw_rate= 0.0
# slip_angle= 0.0
# time_step= 0
#
# vehicle_initial_state:
# position= [ 67.348  377.2854]
# orientation= -2.4137
# velocity= 22.699
# yaw_rate= 0.0
# slip_angle= 0.0
# time_step= 0
#
# vehicle_initial_state.velocity:     22.699
# vehicle_initial_state.position:     [ 67.348  377.2854]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4abbd7850>
# distance_sensor.vehicles_in_range:  [321, 323, 324, 326, 327]
# score_array:      {321: 0.0, 327: 0.0, 323: 255.47362022216595, 324: 255.47362022216595, 326: 255.47362022216595}
# group_array:      [323, 324, 326]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4abfe29d0>
# vehicle_info:     {'id': 35, 'initial_position': array([-87.702 , 243.7694]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4abb44910>, 'initial_lanelet_id': 67, 'initial_lanelet_node': 3, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-87.702  243.7694]
# orientation= -2.4419
# velocity= 16.3085
# acceleration= 1.7957
# time_step= 0
#
# vehicle_initial_state:
# position= [-87.702  243.7694]
# orientation= -2.4419
# velocity= 16.3085
# acceleration= 1.7957
# time_step= 0
#
# vehicle_initial_state.velocity:     16.3085
# vehicle_initial_state.position:     [-87.702  243.7694]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92c7f50>
# distance_sensor.vehicles_in_range:  [311, 315]
# score_array:      {311: 10.072084910409572, 315: 28.58138330930538}
# group_array:      [311, 315]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92c7fd0>
# vehicle_info:     {'id': 39, 'initial_position': array([-130.5919,  198.8162]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9b61050>, 'initial_lanelet_id': 60, 'initial_lanelet_node': 5, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-130.5919  198.8162]
# orientation= -2.1871
# velocity= 23.4588
# acceleration= 0.5537
# time_step= 0
#
# vehicle_initial_state:
# position= [-130.5919  198.8162]
# orientation= -2.1871
# velocity= 23.4588
# acceleration= 0.5537
# time_step= 0
#
# vehicle_initial_state.velocity:     23.4588
# vehicle_initial_state.position:     [-130.5919  198.8162]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9610>
# distance_sensor.vehicles_in_range:  [311]
# score_array:      {311: 0.0}
# group_array:      []
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9650>
# vehicle_info:     {'id': 311, 'initial_position': array([-97.9548, 229.5944]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9b62550>, 'initial_lanelet_id': 60, 'initial_lanelet_node': 0, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-97.9548 229.5944]
# orientation= -2.4968
# velocity= 25.4455
# acceleration= -0.6492
# time_step= 0
#
# vehicle_initial_state:
# position= [-97.9548 229.5944]
# orientation= -2.4968
# velocity= 25.4455
# acceleration= -0.6492
# time_step= 0
#
# vehicle_initial_state.velocity:     25.4455
# vehicle_initial_state.position:     [-97.9548 229.5944]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9690>
# distance_sensor.vehicles_in_range:  [35, 39, 315]
# score_array:      {39: 0.0, 35: 10.072084910409572, 315: 28.58138330930538}
# group_array:      [35, 315]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e96d0>
# vehicle_info:     {'id': 313, 'initial_position': array([-22.8032, 297.0531]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9b6ee10>, 'initial_lanelet_id': 62, 'initial_lanelet_node': 0, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-22.8032 297.0531]
# orientation= -2.4246
# velocity= 22.4416
# acceleration= 0.0902
# time_step= 0
#
# vehicle_initial_state:
# position= [-22.8032 297.0531]
# orientation= -2.4246
# velocity= 22.4416
# acceleration= 0.0902
# time_step= 0
#
# vehicle_initial_state.velocity:     22.4416
# vehicle_initial_state.position:     [-22.8032 297.0531]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9710>
# distance_sensor.vehicles_in_range:  [317, 318, 320, 322]
# score_array:      {318: 1.0658141036401503e-14, 317: 106.28953960836328, 320: 106.28953960836328, 322: 140.02850446117304}
# group_array:      [317, 320, 322]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9750>
# vehicle_info:     {'id': 315, 'initial_position': array([-66.1657, 250.5458]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9b09cd0>, 'initial_lanelet_id': 63, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-66.1657 250.5458]
# orientation= -2.611
# velocity= 23.5856
# acceleration= 1.6903
# time_step= 0
#
# vehicle_initial_state:
# position= [-66.1657 250.5458]
# orientation= -2.611
# velocity= 23.5856
# acceleration= 1.6903
# time_step= 0
#
# vehicle_initial_state.velocity:     23.5856
# vehicle_initial_state.position:     [-66.1657 250.5458]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9790>
# distance_sensor.vehicles_in_range:  [35, 311, 317]
# score_array:      {317: 4.625613207295132, 35: 28.58138330930538, 311: 28.58138330930538}
# group_array:      [35, 311, 317]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e97d0>
# vehicle_info:     {'id': 317, 'initial_position': array([-34.8287, 267.4852]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9b3b7d0>, 'initial_lanelet_id': 64, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-34.8287 267.4852]
# orientation= -2.568
# velocity= 18.7462
# acceleration= -3.1206
# time_step= 0
#
# vehicle_initial_state:
# position= [-34.8287 267.4852]
# orientation= -2.568
# velocity= 18.7462
# acceleration= -3.1206
# time_step= 0
#
# vehicle_initial_state.velocity:     18.7462
# vehicle_initial_state.position:     [-34.8287 267.4852]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9810>
# distance_sensor.vehicles_in_range:  [313, 315, 320]
# score_array:      {315: 4.625613207295132, 320: 11.035949526547334, 313: 106.28953960836328}
# group_array:      [313, 315, 320]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9850>
# vehicle_info:     {'id': 318, 'initial_position': array([  8.049 , 324.4364]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9ad87d0>, 'initial_lanelet_id': 59, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [  8.049  324.4364]
# orientation= -2.4136
# velocity= 24.2938
# acceleration= -0.024
# time_step= 0
#
# vehicle_initial_state:
# position= [  8.049  324.4364]
# orientation= -2.4136
# velocity= 24.2938
# acceleration= -0.024
# time_step= 0
#
# vehicle_initial_state.velocity:     24.2938
# vehicle_initial_state.position:     [  8.049  324.4364]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9890>
# distance_sensor.vehicles_in_range:  [313, 319, 320, 321, 322, 324]
# score_array:      {321: 0, 313: 1.0658141036401503e-14, 320: 106.28953960836328, 319: 140.02850446117304, 322: 140.02850446117304, 324: 182.6733837462936}
# group_array:      [320, 319, 322, 324]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9910>
# vehicle_info:     {'id': 319, 'initial_position': array([ 30.674 , 324.2206]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9a8c690>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 13, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 30.674  324.2206]
# orientation= -2.4134
# velocity= 21.9676
# acceleration= -2.5321
# time_step= 0
#
# vehicle_initial_state:
# position= [ 30.674  324.2206]
# orientation= -2.4134
# velocity= 21.9676
# acceleration= -2.5321
# time_step= 0
#
# vehicle_initial_state.velocity:     21.9676
# vehicle_initial_state.position:     [ 30.674  324.2206]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9950>
# distance_sensor.vehicles_in_range:  [318, 321, 322, 323, 324]
# score_array:      {322: 0, 323: 0, 324: 0, 318: 140.02850446117304, 321: 180.88154664854488}
# group_array:      [318, 321]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e99d0>
# vehicle_info:     {'id': 320, 'initial_position': array([-10.5665, 284.8248]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9a4ae10>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 16, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-10.5665 284.8248]
# orientation= -2.4914
# velocity= 19.6346
# acceleration= -1.6412
# time_step= 0
#
# vehicle_initial_state:
# position= [-10.5665 284.8248]
# orientation= -2.4914
# velocity= 19.6346
# acceleration= -1.6412
# time_step= 0
#
# vehicle_initial_state.velocity:     19.6346
# vehicle_initial_state.position:     [-10.5665 284.8248]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9a10>
# distance_sensor.vehicles_in_range:  [313, 317, 318, 322]
# score_array:      {322: 0, 317: 11.035949526547334, 313: 106.28953960836328, 318: 106.28953960836328}
# group_array:      [313, 317, 318]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9a50>
# vehicle_info:     {'id': 321, 'initial_position': array([ 39.1096, 352.1208]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9a11190>, 'initial_lanelet_id': 59, 'initial_lanelet_node': 1, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 39.1096 352.1208]
# orientation= -2.4137
# velocity= 25.36
# acceleration= 1.4723
# time_step= 0
#
# vehicle_initial_state:
# position= [ 39.1096 352.1208]
# orientation= -2.4137
# velocity= 25.36
# acceleration= 1.4723
# time_step= 0
#
# vehicle_initial_state.velocity:     25.36
# vehicle_initial_state.position:     [ 39.1096 352.1208]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9a90>
# distance_sensor.vehicles_in_range:  [-1, 318, 319, 322, 323, 324, 326]
# score_array:      {-1: 0.0, 318: 0, 319: 180.88154664854488, 322: 180.88154664854488, 324: 182.6733837462936, 323: 201.23627332880466, 326: 201.23627332880466}
# group_array:      [319, 322, 324, 323, 326]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9b10>
# vehicle_info:     {'id': 322, 'initial_position': array([ 18.23  , 308.4819]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a99d6e10>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 13, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 18.23   308.4819]
# orientation= -2.4287
# velocity= 21.5555
# acceleration= -4.1209
# time_step= 0
#
# vehicle_initial_state:
# position= [ 18.23   308.4819]
# orientation= -2.4287
# velocity= 21.5555
# acceleration= -4.1209
# time_step= 0
#
# vehicle_initial_state.velocity:     21.5555
# vehicle_initial_state.position:     [ 18.23   308.4819]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9b50>
# distance_sensor.vehicles_in_range:  [313, 318, 319, 320, 321, 324]
# score_array:      {319: 0, 320: 0, 324: 0, 313: 140.02850446117304, 318: 140.02850446117304, 321: 180.88154664854488}
# group_array:      [313, 318, 321]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9bd0>
# vehicle_info:     {'id': 323, 'initial_position': array([ 59.0238, 349.2613]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a995f050>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 11, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 59.0238 349.2613]
# orientation= -2.4269
# velocity= 22.4868
# acceleration= 1.4001
# time_step= 0
#
# vehicle_initial_state:
# position= [ 59.0238 349.2613]
# orientation= -2.4269
# velocity= 22.4868
# acceleration= 1.4001
# time_step= 0
#
# vehicle_initial_state.velocity:     22.4868
# vehicle_initial_state.position:     [ 59.0238 349.2613]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9c10>
# distance_sensor.vehicles_in_range:  [-1, 319, 321, 324, 326]
# score_array:      {319: 0, 324: 0, 326: 0, 321: 201.23627332880466, -1: 255.47362022216595}
# group_array:      [-1, 321]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9c90>
# vehicle_info:     {'id': 324, 'initial_position': array([ 47.963 , 334.9498]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9976cd0>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 12, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 47.963  334.9498]
# orientation= -2.4133
# velocity= 23.6817
# acceleration= -1.3191
# time_step= 0
#
# vehicle_initial_state:
# position= [ 47.963  334.9498]
# orientation= -2.4133
# velocity= 23.6817
# acceleration= -1.3191
# time_step= 0
#
# vehicle_initial_state.velocity:     23.6817
# vehicle_initial_state.position:     [ 47.963  334.9498]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9cd0>
# distance_sensor.vehicles_in_range:  [-1, 318, 319, 321, 322, 323, 326]
# score_array:      {319: 0, 322: 0, 323: 0, 326: 0, 318: 182.6733837462936, 321: 182.6733837462936, -1: 255.47362022216595}
# group_array:      [-1, 318, 321]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9d50>
# vehicle_info:     {'id': 326, 'initial_position': array([ 73.9127, 357.5201]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a98d4cd0>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 11, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 73.9127 357.5201]
# orientation= -2.4286
# velocity= 21.0765
# acceleration= 1.7579
# time_step= 0
#
# vehicle_initial_state:
# position= [ 73.9127 357.5201]
# orientation= -2.4286
# velocity= 21.0765
# acceleration= 1.7579
# time_step= 0
#
# vehicle_initial_state.velocity:     21.0765
# vehicle_initial_state.position:     [ 73.9127 357.5201]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9d90>
# distance_sensor.vehicles_in_range:  [-1, 321, 323, 324, 327]
# score_array:      {323: 0, 324: 0, 321: 201.23627332880466, -1: 255.47362022216595, 327: 255.473620222166}
# group_array:      [-1, 321, 327]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9e10>
# vehicle_info:     {'id': 327, 'initial_position': array([ 94.6548, 401.6375]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9866050>, 'initial_lanelet_id': 65, 'initial_lanelet_node': 3, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 94.6548 401.6375]
# orientation= -2.4084
# velocity= 18.8144
# acceleration= 2.411
# time_step= 0
#
# vehicle_initial_state:
# position= [ 94.6548 401.6375]
# orientation= -2.4084
# velocity= 18.8144
# acceleration= 2.411
# time_step= 0
#
# vehicle_initial_state.velocity:     18.8144
# vehicle_initial_state.position:     [ 94.6548 401.6375]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9e50>
# distance_sensor.vehicles_in_range:  [-1, 326, 328]
# score_array:      {-1: 0.0, 328: 3.552713678800501e-15, 326: 255.473620222166}
# group_array:      [326]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9e90>
# vehicle_info:     {'id': 328, 'initial_position': array([114.5878, 421.2139]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a9801b90>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [114.5878 421.2139]
# orientation= -2.332
# velocity= 15.8235
# acceleration= 2.294
# time_step= 0
#
# vehicle_initial_state:
# position= [114.5878 421.2139]
# orientation= -2.332
# velocity= 15.8235
# acceleration= 2.294
# time_step= 0
#
# vehicle_initial_state.velocity:     15.8235
# vehicle_initial_state.position:     [114.5878 421.2139]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9ed0>
# distance_sensor.vehicles_in_range:  [327, 329, 330]
# score_array:      {329: 0, 330: 0, 327: 3.552713678800501e-15}
# group_array:      []
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9f10>
# vehicle_info:     {'id': 329, 'initial_position': array([134.6273, 442.2464]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a97f37d0>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 1, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [134.6273 442.2464]
# orientation= -2.3321
# velocity= 11.3675
# acceleration= 1.7994
# time_step= 0
#
# vehicle_initial_state:
# position= [134.6273 442.2464]
# orientation= -2.3321
# velocity= 11.3675
# acceleration= 1.7994
# time_step= 0
#
# vehicle_initial_state.velocity:     11.3675
# vehicle_initial_state.position:     [134.6273 442.2464]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9f50>
# distance_sensor.vehicles_in_range:  [328, 330, 331]
# score_array:      {328: 0, 330: 0, 331: 0.0}
# group_array:      []
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92e9f90>
# vehicle_info:     {'id': 330, 'initial_position': array([145.9309, 454.1039]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a975e410>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 1, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [145.9309 454.1039]
# orientation= -2.3323
# velocity= 8.2769
# acceleration= 1.5782
# time_step= 0
#
# vehicle_initial_state:
# position= [145.9309 454.1039]
# orientation= -2.3323
# velocity= 8.2769
# acceleration= 1.5782
# time_step= 0
#
# vehicle_initial_state.velocity:     8.2769
# vehicle_initial_state.position:     [145.9309 454.1039]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92e9fd0>
# distance_sensor.vehicles_in_range:  [328, 329, 331]
# score_array:      {328: 0, 329: 0, 331: 0.0}
# group_array:      []
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fc4a92ee050>
# vehicle_info:     {'id': 331, 'initial_position': array([153.7147, 462.2688]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fc4a96a0050>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 0, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [153.7147 462.2688]
# orientation= -2.3323
# velocity= 5.2449
# acceleration= 1.3603
# time_step= 0
#
# vehicle_initial_state:
# position= [153.7147 462.2688]
# orientation= -2.3323
# velocity= 5.2449
# acceleration= 1.3603
# time_step= 0
#
# vehicle_initial_state.velocity:     5.2449
# vehicle_initial_state.position:     [153.7147 462.2688]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fc4d82262d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fc4a92ee090>
# distance_sensor.vehicles_in_range:  [329, 330]
# score_array:      {329: 0.0, 330: 0.0}
# group_array:      []
# knowledge_base:   None
# ___________________________________________________________________________________________________

# %%
def GetUniqueIdForGroups():
    
    return 1


import numpy as np
group_ids = dict()
for vehicle_dict_id in vehicle_objects:
    
    group_array = vehicle_objects[vehicle_dict_id].group_array
    
    if vehicle_dict_id not in group_array: group_array.append(vehicle_dict_id)
    group_array = np.sort(group_array)
    if vehicle_dict_id not in group_ids:
        for vc_id in vehicle_objects:

            group_array2 = vehicle_objects[vc_id].group_array

            if vc_id not in group_array2: group_array2.append(vc_id)
            group_array2 = np.sort(group_array2)

            if np.array_equal(np.array(group_array), np.array(group_array2)) and vehicle_dict_id != vc_id:
                if vc_id in group_ids: #isGroupHasId(vc_id):
                    group_ids[vehicle_dict_id] = group_ids[vc_id]
                else:
                    group_ids[vehicle_dict_id] = vehicle_objects[vc_id].__GroupUniqueIDGenerator()()
                    group_ids[vc_id] = group_ids[vehicle_dict_id]
    if vehicle_dict_id not in group_ids:
        group_ids[vehicle_dict_id] = vehicle_objects[vc_id].__GroupUniqueIDGenerator()
print(group_ids)
# Out:
# 'def GetUniqueIdForGroups():\n    \n    return 1\n\n\nimport numpy as np\ngroup_ids = dict()\nfor vehicle_dict_id in vehicle_objects:\n    \n    group_array = vehicle_objects[vehicle_dict_id].group_array\n    \n    if vehicle_dict_id not in group_array: group_array.append(vehicle_dict_id)\n    group_array = np.sort(group_array)\n    if vehicle_dict_id not in group_ids:\n        for vc_id in vehicle_objects:\n\n            group_array2 = vehicle_objects[vc_id].group_array\n\n            if vc_id not in group_array2: group_array2.append(vc_id)\n            group_array2 = np.sort(group_array2)\n\n            if np.array_equal(np.array(group_array), np.array(group_array2)) and vehicle_dict_id != vc_id:\n                if vc_id in group_ids: #isGroupHasId(vc_id):\n                    group_ids[vehicle_dict_id] = group_ids[vc_id]\n                else:\n                    group_ids[vehicle_dict_id] = GetUniqueIdForGroups()\n                    group_ids[vc_id] = group_ids[vehicle_dict_id]\n    if vehicle_dict_id not in group_ids:\n        group_ids[vehicle_dict_id] = GetUniqueIdForGroups()\nprint(group_ids)'

# %%
from Visualization import VisualizationFunctions
visualization = VisualizationFunctions(SG_1)
print(visualization.group_ids)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-073fd5e30a16> in <module>()
#       1 from Visualization import VisualizationFunctions
# ----> 2 visualization = VisualizationFunctions(SG_1)
#       3 print(visualization.group_ids)
#
# /home/melike/Documents/TUM/20S/Praktikum/MyPraktikum/CCFCG/group-formation/Visualization.py in __init__(self, scenario_graph)
#       9         self.first_group_id = None
#      10         self.unique_group_ids = list()
# ---> 11         self.group_ids = self.__CollectGroupArrayConstructers()
#      12
#      13
#
# /home/melike/Documents/TUM/20S/Praktikum/MyPraktikum/CCFCG/group-formation/Visualization.py in __CollectGroupArrayConstructers(self)
#      46                             group_ids[vc_id] = group_ids[vehicle_dict_id]
#      47             if vehicle_dict_id not in group_ids:
# ---> 48                 group_ids[vehicle_dict_id] = GetUniqueIdForGroups()
#      49
#      50         return group_ids
#
# NameError: name 'GetUniqueIdForGroups' is not defined
