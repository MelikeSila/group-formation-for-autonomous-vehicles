# %%
from GraphBasedDistanceMeasure import ScenarioGraph
from commonroad.common.file_reader import CommonRoadFileReader
import networkx as nx
import matplotlib.pyplot as plt

# generate path of the file to be opened
#file_path = "data_files/ZAM_Tutorial-1_1_T-1.xml"
#file_path2 = "data_files/ZAM_Tjunction-1_66_T-1.xml"
file_path = "data_files/CHN_Cho-2_1_T-1.xml"
file_path2 = "data_files/DEU_A9-1_1_T-1.xml"

# read in the scenario and planning problem set
crf = CommonRoadFileReader(file_path)
scenario, planning_problem_set = crf.open()

crf2 = CommonRoadFileReader(file_path2)
scenario2, planning_problem_set2 = crf2.open()

#for graph attributes
options1 = {
    'node_color': 'lightgreen',
    'node_size': 1000,
    'width': 1,
}

options2 = {
    'node_color': 'green',
    'node_size': 500,
    'width': 1,
}

plt.rcParams['figure.figsize'] = (20.0, 20.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

#################################BRIEF USAGE###############################################
###########################################################################################
#############################GBDM Sample Usage ############################################
###########################################################################################
#Creata an ScenariGraph object
SG_1 = ScenarioGraph(scenario, planning_problem_set)
SG_2 = ScenarioGraph(scenario2, planning_problem_set2)
#SG_1.CreateLaneletGraph()  #you dont need to create graph. It created in constructer method

plt.subplot(1, 2, 1)
nx.draw(SG_1.scenario_graph,with_labels=True, font_weight='bold', **options1)
plt.subplot(1, 2, 2)
nx.draw(SG_2.scenario_graph,with_labels=True, font_weight='bold', **options2)
plt.show()
# Out:
# /home/melike/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/melike/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
vehicle_objects = SG_1.vehicle_objects_dict

for vehicle_dict_id in vehicle_objects:
    print("vehicle object:  ", vehicle_objects[vehicle_dict_id])
    print("vehicle_info:    ", vehicle_objects[vehicle_dict_id].vehicle_info)
    
    #Initial_state usage
    print("**vehicle_info.initial_state:    ", (vehicle_objects[vehicle_dict_id].vehicle_info["initial_state"]))
    print("vehicle_initial_state:    ", vehicle_objects[vehicle_dict_id].vehicle_initial_state)
    print("vehicle_initial_state.velocity:    ", vehicle_objects[vehicle_dict_id].vehicle_initial_state.velocity)
    print("vehicle_initial_state.position:    ", vehicle_objects[vehicle_dict_id].vehicle_initial_state.position)
    
    
    print("vehicle_graph:   ", vehicle_objects[vehicle_dict_id].vehicle_graph)
    print("distance_sensor: ", vehicle_objects[vehicle_dict_id].distance_sensor)
    print("distance_sensor.vehicles_in_range: ", vehicle_objects[vehicle_dict_id].distance_sensor.vehicles_in_range)
    print("score_array:     ", vehicle_objects[vehicle_dict_id].score_dict)
    print("group_array:     ", vehicle_objects[vehicle_dict_id].group_array)
    print("knowledge_base:  ", vehicle_objects[vehicle_dict_id].knowledge_base)
    
    print("___________________________________________________________________________________________________")
# Out:
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19cf2b4d0>
# vehicle_info:     {'id': -1, 'initial_position': array([ 67.348 , 377.2854]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19a7e3b90>, 'initial_lanelet_id': 59, 'initial_lanelet_node': 0, 'planning_problem_id': 1}
# **vehicle_info.initial_state:
# position= [ 67.348  377.2854]
# orientation= -2.4137
# velocity= 22.699
# yaw_rate= 0.0
# slip_angle= 0.0
# time_step= 0
#
# vehicle_initial_state:
# position= [ 67.348  377.2854]
# orientation= -2.4137
# velocity= 22.699
# yaw_rate= 0.0
# slip_angle= 0.0
# time_step= 0
#
# vehicle_initial_state.velocity:     22.699
# vehicle_initial_state.position:     [ 67.348  377.2854]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19cf26a10>
# distance_sensor.vehicles_in_range:  [321, 323, 324, 326, 327]
# score_array:      {321: 0.0, 327: 0.0, 323: 255.47362022216595, 324: 255.47362022216595, 326: 255.47362022216595}
# group_array:      [323, 324, 326]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a3ecf50>
# vehicle_info:     {'id': 35, 'initial_position': array([-87.702 , 243.7694]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19cc6a910>, 'initial_lanelet_id': 67, 'initial_lanelet_node': 3, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-87.702  243.7694]
# orientation= -2.4419
# velocity= 16.3085
# acceleration= 1.7957
# time_step= 0
#
# vehicle_initial_state:
# position= [-87.702  243.7694]
# orientation= -2.4419
# velocity= 16.3085
# acceleration= 1.7957
# time_step= 0
#
# vehicle_initial_state.velocity:     16.3085
# vehicle_initial_state.position:     [-87.702  243.7694]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a3ec8d0>
# distance_sensor.vehicles_in_range:  [311, 315]
# score_array:      {311: 10.072084910409572, 315: 28.58138330930538}
# group_array:      [311, 315]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a3ecf90>
# vehicle_info:     {'id': 39, 'initial_position': array([-130.5919,  198.8162]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19ac89050>, 'initial_lanelet_id': 60, 'initial_lanelet_node': 5, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-130.5919  198.8162]
# orientation= -2.1871
# velocity= 23.4588
# acceleration= 0.5537
# time_step= 0
#
# vehicle_initial_state:
# position= [-130.5919  198.8162]
# orientation= -2.1871
# velocity= 23.4588
# acceleration= 0.5537
# time_step= 0
#
# vehicle_initial_state.velocity:     23.4588
# vehicle_initial_state.position:     [-130.5919  198.8162]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40f550>
# distance_sensor.vehicles_in_range:  [311]
# score_array:      {311: 0.0}
# group_array:      []
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40f590>
# vehicle_info:     {'id': 311, 'initial_position': array([-97.9548, 229.5944]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19ac8a550>, 'initial_lanelet_id': 60, 'initial_lanelet_node': 0, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-97.9548 229.5944]
# orientation= -2.4968
# velocity= 25.4455
# acceleration= -0.6492
# time_step= 0
#
# vehicle_initial_state:
# position= [-97.9548 229.5944]
# orientation= -2.4968
# velocity= 25.4455
# acceleration= -0.6492
# time_step= 0
#
# vehicle_initial_state.velocity:     25.4455
# vehicle_initial_state.position:     [-97.9548 229.5944]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40f5d0>
# distance_sensor.vehicles_in_range:  [35, 39, 315]
# score_array:      {39: 0.0, 35: 10.072084910409572, 315: 28.58138330930538}
# group_array:      [35, 315]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40f610>
# vehicle_info:     {'id': 313, 'initial_position': array([-22.8032, 297.0531]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19ac96e10>, 'initial_lanelet_id': 62, 'initial_lanelet_node': 0, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-22.8032 297.0531]
# orientation= -2.4246
# velocity= 22.4416
# acceleration= 0.0902
# time_step= 0
#
# vehicle_initial_state:
# position= [-22.8032 297.0531]
# orientation= -2.4246
# velocity= 22.4416
# acceleration= 0.0902
# time_step= 0
#
# vehicle_initial_state.velocity:     22.4416
# vehicle_initial_state.position:     [-22.8032 297.0531]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40f650>
# distance_sensor.vehicles_in_range:  [317, 318, 320, 322]
# score_array:      {318: 1.0658141036401503e-14, 317: 106.28953960836328, 320: 106.28953960836328, 322: 140.02850446117304}
# group_array:      [317, 320, 322]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40f690>
# vehicle_info:     {'id': 315, 'initial_position': array([-66.1657, 250.5458]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19ac31cd0>, 'initial_lanelet_id': 63, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-66.1657 250.5458]
# orientation= -2.611
# velocity= 23.5856
# acceleration= 1.6903
# time_step= 0
#
# vehicle_initial_state:
# position= [-66.1657 250.5458]
# orientation= -2.611
# velocity= 23.5856
# acceleration= 1.6903
# time_step= 0
#
# vehicle_initial_state.velocity:     23.5856
# vehicle_initial_state.position:     [-66.1657 250.5458]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40f6d0>
# distance_sensor.vehicles_in_range:  [35, 311, 317]
# score_array:      {317: 4.625613207295132, 35: 28.58138330930538, 311: 28.58138330930538}
# group_array:      [35, 311, 317]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40f710>
# vehicle_info:     {'id': 317, 'initial_position': array([-34.8287, 267.4852]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19ac637d0>, 'initial_lanelet_id': 64, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-34.8287 267.4852]
# orientation= -2.568
# velocity= 18.7462
# acceleration= -3.1206
# time_step= 0
#
# vehicle_initial_state:
# position= [-34.8287 267.4852]
# orientation= -2.568
# velocity= 18.7462
# acceleration= -3.1206
# time_step= 0
#
# vehicle_initial_state.velocity:     18.7462
# vehicle_initial_state.position:     [-34.8287 267.4852]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40f750>
# distance_sensor.vehicles_in_range:  [313, 315, 320]
# score_array:      {315: 4.625613207295132, 320: 11.035949526547334, 313: 106.28953960836328}
# group_array:      [313, 315, 320]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40f790>
# vehicle_info:     {'id': 318, 'initial_position': array([  8.049 , 324.4364]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19ac007d0>, 'initial_lanelet_id': 59, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [  8.049  324.4364]
# orientation= -2.4136
# velocity= 24.2938
# acceleration= -0.024
# time_step= 0
#
# vehicle_initial_state:
# position= [  8.049  324.4364]
# orientation= -2.4136
# velocity= 24.2938
# acceleration= -0.024
# time_step= 0
#
# vehicle_initial_state.velocity:     24.2938
# vehicle_initial_state.position:     [  8.049  324.4364]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40f7d0>
# distance_sensor.vehicles_in_range:  [313, 319, 320, 321, 322, 324]
# score_array:      {321: 0, 313: 1.0658141036401503e-14, 320: 106.28953960836328, 319: 140.02850446117304, 322: 140.02850446117304, 324: 182.6733837462936}
# group_array:      [320, 319, 322, 324]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40f850>
# vehicle_info:     {'id': 319, 'initial_position': array([ 30.674 , 324.2206]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19abb4690>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 13, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 30.674  324.2206]
# orientation= -2.4134
# velocity= 21.9676
# acceleration= -2.5321
# time_step= 0
#
# vehicle_initial_state:
# position= [ 30.674  324.2206]
# orientation= -2.4134
# velocity= 21.9676
# acceleration= -2.5321
# time_step= 0
#
# vehicle_initial_state.velocity:     21.9676
# vehicle_initial_state.position:     [ 30.674  324.2206]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40f890>
# distance_sensor.vehicles_in_range:  [318, 321, 322, 323, 324]
# score_array:      {322: 0, 323: 0, 324: 0, 318: 140.02850446117304, 321: 180.88154664854488}
# group_array:      [318, 321]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40f910>
# vehicle_info:     {'id': 320, 'initial_position': array([-10.5665, 284.8248]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19ab72e10>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 16, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-10.5665 284.8248]
# orientation= -2.4914
# velocity= 19.6346
# acceleration= -1.6412
# time_step= 0
#
# vehicle_initial_state:
# position= [-10.5665 284.8248]
# orientation= -2.4914
# velocity= 19.6346
# acceleration= -1.6412
# time_step= 0
#
# vehicle_initial_state.velocity:     19.6346
# vehicle_initial_state.position:     [-10.5665 284.8248]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40f950>
# distance_sensor.vehicles_in_range:  [313, 317, 318, 322]
# score_array:      {322: 0, 317: 11.035949526547334, 313: 106.28953960836328, 318: 106.28953960836328}
# group_array:      [313, 317, 318]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40f990>
# vehicle_info:     {'id': 321, 'initial_position': array([ 39.1096, 352.1208]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19ab39190>, 'initial_lanelet_id': 59, 'initial_lanelet_node': 1, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 39.1096 352.1208]
# orientation= -2.4137
# velocity= 25.36
# acceleration= 1.4723
# time_step= 0
#
# vehicle_initial_state:
# position= [ 39.1096 352.1208]
# orientation= -2.4137
# velocity= 25.36
# acceleration= 1.4723
# time_step= 0
#
# vehicle_initial_state.velocity:     25.36
# vehicle_initial_state.position:     [ 39.1096 352.1208]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40f9d0>
# distance_sensor.vehicles_in_range:  [-1, 318, 319, 322, 323, 324, 326]
# score_array:      {-1: 0.0, 318: 0, 319: 180.88154664854488, 322: 180.88154664854488, 324: 182.6733837462936, 323: 201.23627332880466, 326: 201.23627332880466}
# group_array:      [319, 322, 324, 323, 326]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40fa50>
# vehicle_info:     {'id': 322, 'initial_position': array([ 18.23  , 308.4819]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19aafee10>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 13, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 18.23   308.4819]
# orientation= -2.4287
# velocity= 21.5555
# acceleration= -4.1209
# time_step= 0
#
# vehicle_initial_state:
# position= [ 18.23   308.4819]
# orientation= -2.4287
# velocity= 21.5555
# acceleration= -4.1209
# time_step= 0
#
# vehicle_initial_state.velocity:     21.5555
# vehicle_initial_state.position:     [ 18.23   308.4819]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40fa90>
# distance_sensor.vehicles_in_range:  [313, 318, 319, 320, 321, 324]
# score_array:      {319: 0, 320: 0, 324: 0, 313: 140.02850446117304, 318: 140.02850446117304, 321: 180.88154664854488}
# group_array:      [313, 318, 321]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40fb10>
# vehicle_info:     {'id': 323, 'initial_position': array([ 59.0238, 349.2613]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19aa87050>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 11, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 59.0238 349.2613]
# orientation= -2.4269
# velocity= 22.4868
# acceleration= 1.4001
# time_step= 0
#
# vehicle_initial_state:
# position= [ 59.0238 349.2613]
# orientation= -2.4269
# velocity= 22.4868
# acceleration= 1.4001
# time_step= 0
#
# vehicle_initial_state.velocity:     22.4868
# vehicle_initial_state.position:     [ 59.0238 349.2613]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40fb50>
# distance_sensor.vehicles_in_range:  [-1, 319, 321, 324, 326]
# score_array:      {319: 0, 324: 0, 326: 0, 321: 201.23627332880466, -1: 255.47362022216595}
# group_array:      [-1, 321]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40fbd0>
# vehicle_info:     {'id': 324, 'initial_position': array([ 47.963 , 334.9498]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19aa9ecd0>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 12, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 47.963  334.9498]
# orientation= -2.4133
# velocity= 23.6817
# acceleration= -1.3191
# time_step= 0
#
# vehicle_initial_state:
# position= [ 47.963  334.9498]
# orientation= -2.4133
# velocity= 23.6817
# acceleration= -1.3191
# time_step= 0
#
# vehicle_initial_state.velocity:     23.6817
# vehicle_initial_state.position:     [ 47.963  334.9498]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40fc10>
# distance_sensor.vehicles_in_range:  [-1, 318, 319, 321, 322, 323, 326]
# score_array:      {319: 0, 322: 0, 323: 0, 326: 0, 318: 182.6733837462936, 321: 182.6733837462936, -1: 255.47362022216595}
# group_array:      [-1, 318, 321]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40fc90>
# vehicle_info:     {'id': 326, 'initial_position': array([ 73.9127, 357.5201]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19a9fccd0>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 11, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 73.9127 357.5201]
# orientation= -2.4286
# velocity= 21.0765
# acceleration= 1.7579
# time_step= 0
#
# vehicle_initial_state:
# position= [ 73.9127 357.5201]
# orientation= -2.4286
# velocity= 21.0765
# acceleration= 1.7579
# time_step= 0
#
# vehicle_initial_state.velocity:     21.0765
# vehicle_initial_state.position:     [ 73.9127 357.5201]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40fcd0>
# distance_sensor.vehicles_in_range:  [-1, 321, 323, 324, 327]
# score_array:      {323: 0, 324: 0, 321: 201.23627332880466, -1: 255.47362022216595, 327: 255.473620222166}
# group_array:      [-1, 321, 327]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40fd50>
# vehicle_info:     {'id': 327, 'initial_position': array([ 94.6548, 401.6375]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19a98e050>, 'initial_lanelet_id': 65, 'initial_lanelet_node': 3, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 94.6548 401.6375]
# orientation= -2.4084
# velocity= 18.8144
# acceleration= 2.411
# time_step= 0
#
# vehicle_initial_state:
# position= [ 94.6548 401.6375]
# orientation= -2.4084
# velocity= 18.8144
# acceleration= 2.411
# time_step= 0
#
# vehicle_initial_state.velocity:     18.8144
# vehicle_initial_state.position:     [ 94.6548 401.6375]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40fd90>
# distance_sensor.vehicles_in_range:  [-1, 326, 328]
# score_array:      {-1: 0.0, 328: 3.552713678800501e-15, 326: 255.473620222166}
# group_array:      [326]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40fdd0>
# vehicle_info:     {'id': 328, 'initial_position': array([114.5878, 421.2139]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19a929b90>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [114.5878 421.2139]
# orientation= -2.332
# velocity= 15.8235
# acceleration= 2.294
# time_step= 0
#
# vehicle_initial_state:
# position= [114.5878 421.2139]
# orientation= -2.332
# velocity= 15.8235
# acceleration= 2.294
# time_step= 0
#
# vehicle_initial_state.velocity:     15.8235
# vehicle_initial_state.position:     [114.5878 421.2139]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40fe10>
# distance_sensor.vehicles_in_range:  [327, 329, 330]
# score_array:      {329: 0, 330: 0, 327: 3.552713678800501e-15}
# group_array:      []
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40fe50>
# vehicle_info:     {'id': 329, 'initial_position': array([134.6273, 442.2464]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19a91b7d0>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 1, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [134.6273 442.2464]
# orientation= -2.3321
# velocity= 11.3675
# acceleration= 1.7994
# time_step= 0
#
# vehicle_initial_state:
# position= [134.6273 442.2464]
# orientation= -2.3321
# velocity= 11.3675
# acceleration= 1.7994
# time_step= 0
#
# vehicle_initial_state.velocity:     11.3675
# vehicle_initial_state.position:     [134.6273 442.2464]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40fe90>
# distance_sensor.vehicles_in_range:  [328, 330, 331]
# score_array:      {328: 0, 330: 0, 331: 0.0}
# group_array:      []
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40fed0>
# vehicle_info:     {'id': 330, 'initial_position': array([145.9309, 454.1039]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19a886410>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 1, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [145.9309 454.1039]
# orientation= -2.3323
# velocity= 8.2769
# acceleration= 1.5782
# time_step= 0
#
# vehicle_initial_state:
# position= [145.9309 454.1039]
# orientation= -2.3323
# velocity= 8.2769
# acceleration= 1.5782
# time_step= 0
#
# vehicle_initial_state.velocity:     8.2769
# vehicle_initial_state.position:     [145.9309 454.1039]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40ff10>
# distance_sensor.vehicles_in_range:  [328, 329, 331]
# score_array:      {328: 0, 329: 0, 331: 0.0}
# group_array:      []
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7fb19a40ff50>
# vehicle_info:     {'id': 331, 'initial_position': array([153.7147, 462.2688]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7fb19a7c8050>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 0, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [153.7147 462.2688]
# orientation= -2.3323
# velocity= 5.2449
# acceleration= 1.3603
# time_step= 0
#
# vehicle_initial_state:
# position= [153.7147 462.2688]
# orientation= -2.3323
# velocity= 5.2449
# acceleration= 1.3603
# time_step= 0
#
# vehicle_initial_state.velocity:     5.2449
# vehicle_initial_state.position:     [153.7147 462.2688]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7fb1c83452d0>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7fb19a40ff90>
# distance_sensor.vehicles_in_range:  [329, 330]
# score_array:      {329: 0.0, 330: 0.0}
# group_array:      []
# knowledge_base:   None
# ___________________________________________________________________________________________________

# %%
from Visualization import VisualizationFunctions
visualization_function = VisualizationFunctions(SG_1)
print(visualization_function.group_ids)
# Out:
# {-1: 1, 35: 2, 311: 2, 39: 3, 313: 4, 315: 5, 317: 6, 318: 7, 319: 8, 320: 9, 321: 10, 322: 11, 323: 12, 324: 13, 326: 14, 327: 15, 328: 16, 329: 17, 330: 18, 331: 19}

# %%
import numpy as np
all_groups = list()
for v_o in SG_1.vehicle_objects_dict:
    print(np.sort(SG_1.vehicle_objects_dict[v_o].group_array))
    all_groups.append(SG_1.vehicle_objects_dict[v_o].group_array)
# Out:
# [ -1 323 324 326]
# [ 35 311 315]
# [39]
# [ 35 311 315]
# [313 317 320 322]
# [ 35 311 315 317]
# [313 315 317 320]
# [318 319 320 322 324]
# [318 319 321]
# [313 317 318 320]
# [319 321 322 323 324 326]
# [313 318 321 322]
# [ -1 321 323]
# [ -1 318 321 324]
# [ -1 321 326 327]
# [326 327]
# [328]
# [329]
# [330]
# [331]

# %%
all_groups
# Out:
# [[323, 324, 326, -1],
#  [311, 315, 35],
#  [39],
#  [35, 315, 311],
#  [317, 320, 322, 313],
#  [35, 311, 317, 315],
#  [313, 315, 320, 317],
#  [320, 319, 322, 324, 318],
#  [318, 321, 319],
#  [313, 317, 318, 320],
#  [319, 322, 324, 323, 326, 321],
#  [313, 318, 321, 322],
#  [-1, 321, 323],
#  [-1, 318, 321, 324],
#  [-1, 321, 327, 326],
#  [326, 327],
#  [328],
#  [329],
#  [330],
#  [331]]

# %%
from Visualization import VisualizationFunctions
visualization_function = VisualizationFunctions(SG_1)
#print(visualization_function.group_ids)

import os
import matplotlib.pyplot as plt
from IPython import display
from brute_force import calculate_score
import commonroad.planning
# import functions to read xml file and visualize commonroad objects
from commonroad.common.file_reader import CommonRoadFileReader
from commonroad.visualization.draw_dispatch_cr import draw_object
import scenarios 
import matplotlib.patches as patches
from brute_force import Colorize_groups
import Convert_groups

groups=[]
# calculate_scores
grouparray= [[323, 324, 326, -1], [311, 315, 35], [39]]

for group in grouparray:
    groups.append(Convert_groups.conv_to_obj(scenario, planning_problem_set, group))

print(grouparray)
# plot the scenario for 40 time step, here each time step corresponds to 0.1 second
for i in range(0, 10):
    
    display.clear_output(wait=True)
    
    plt.figure(figsize=(20, 10))
    # plot the scenario at different time step   
    
    ax = plt.gca()
    
    draw_object(scenario.lanelet_network,draw_params={'time_begin': i}) #, plot_limits=plot_limits)
    Colorize_groups.colorize_groups(groups, ax)
    #raw_object(commonroad.planning.planning_problem.PlanningProblemSet.find_planning_problem_by_id(planning_problem_set, 2), draw_params=draw_params)
    #ect=patches.Rectangle((0,0),5,2,linewidth=1,edgecolor='#880000', facecolor='#998822')
    #x.add_patch(rect)
    # plot the planning problem set
    draw_object(planning_problem_set)
    plt.gca().set_aspect('equal')
    plt.show()
# Out:
#   File "/home/melike/Documents/TUM/20S/Praktikum/MyPraktikum/CCFCG/group-formation/brute_force/Colorize_groups.py", line 13
#     draw_params = {'shape': {'facecolor': color}, {'time_begin': i}}
#                                                                    ^
# SyntaxError: invalid syntax
