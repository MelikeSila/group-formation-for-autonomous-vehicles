# %%
from GraphBasedDistanceMeasure import ScenarioGraph
from commonroad.common.file_reader import CommonRoadFileReader
import networkx as nx
import matplotlib.pyplot as plt

# generate path of the file to be opened
#file_path = "data_files/ZAM_Tutorial-1_1_T-1.xml"
#file_path2 = "data_files/ZAM_Tjunction-1_66_T-1.xml"
file_path = "data_files/CHN_Cho-2_1_T-1.xml"
file_path2 = "data_files/DEU_A9-1_1_T-1.xml"

# read in the scenario and planning problem set
crf = CommonRoadFileReader(file_path)
scenario, planning_problem_set = crf.open()

crf2 = CommonRoadFileReader(file_path2)
scenario2, planning_problem_set2 = crf2.open()

#for graph attributes
options1 = {
    'node_color': 'lightgreen',
    'node_size': 1000,
    'width': 1,
}

options2 = {
    'node_color': 'green',
    'node_size': 500,
    'width': 1,
}

plt.rcParams['figure.figsize'] = (20.0, 20.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

#################################BRIEF USAGE###############################################
###########################################################################################
#############################GBDM Sample Usage ############################################
###########################################################################################
#Creata an ScenariGraph object
SG_1 = ScenarioGraph(scenario, planning_problem_set)
SG_2 = ScenarioGraph(scenario2, planning_problem_set2)
#SG_1.CreateLaneletGraph()  #you dont need to create graph. It created in constructer method

plt.subplot(1, 2, 1)
nx.draw(SG_1.scenario_graph,with_labels=True, font_weight='bold', **options1)
plt.subplot(1, 2, 2)
nx.draw(SG_2.scenario_graph,with_labels=True, font_weight='bold', **options2)
plt.show()
# Out:
# /home/melike/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# /home/melike/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes

# %%
vehicle_objects = SG_1.vehicle_objects_dict

for vehicle_dict_id in vehicle_objects:
    print("vehicle object:  ", vehicle_objects[vehicle_dict_id])
    print("vehicle_info:    ", vehicle_objects[vehicle_dict_id].vehicle_info)
    
    #Initial_state usage
    print("**vehicle_info.initial_state:    ", (vehicle_objects[vehicle_dict_id].vehicle_info["initial_state"]))
    print("vehicle_initial_state:    ", vehicle_objects[vehicle_dict_id].vehicle_initial_state)
    print("vehicle_initial_state.velocity:    ", vehicle_objects[vehicle_dict_id].vehicle_initial_state.velocity)
    print("vehicle_initial_state.position:    ", vehicle_objects[vehicle_dict_id].vehicle_initial_state.position)
    
    
    print("vehicle_graph:   ", vehicle_objects[vehicle_dict_id].vehicle_graph)
    print("distance_sensor: ", vehicle_objects[vehicle_dict_id].distance_sensor)
    print("distance_sensor.vehicles_in_range: ", vehicle_objects[vehicle_dict_id].distance_sensor.vehicles_in_range)
    print("score_array:     ", vehicle_objects[vehicle_dict_id].score_dict)
    print("group_array:     ", vehicle_objects[vehicle_dict_id].group_array)
    print("knowledge_base:  ", vehicle_objects[vehicle_dict_id].knowledge_base)
    
    print("___________________________________________________________________________________________________")
# Out:
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14ecd310>
# vehicle_info:     {'id': -1, 'initial_position': array([ 67.348 , 377.2854]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c152c3b90>, 'initial_lanelet_id': 59, 'initial_lanelet_node': 0, 'planning_problem_id': 1}
# **vehicle_info.initial_state:
# position= [ 67.348  377.2854]
# orientation= -2.4137
# velocity= 22.699
# yaw_rate= 0.0
# slip_angle= 0.0
# time_step= 0
#
# vehicle_initial_state:
# position= [ 67.348  377.2854]
# orientation= -2.4137
# velocity= 22.699
# yaw_rate= 0.0
# slip_angle= 0.0
# time_step= 0
#
# vehicle_initial_state.velocity:     22.699
# vehicle_initial_state.position:     [ 67.348  377.2854]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14ecd610>
# distance_sensor.vehicles_in_range:  [318, 321, 327, 328]
# score_array:      {318: 5.0, 321: 5.0, 327: 5.0, 328: 28.78465348598317}
# group_array:      [318, 321, 327, 328]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14ecd810>
# vehicle_info:     {'id': 35, 'initial_position': array([-87.702 , 243.7694]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c17749910>, 'initial_lanelet_id': 67, 'initial_lanelet_node': 3, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-87.702  243.7694]
# orientation= -2.4419
# velocity= 16.3085
# acceleration= 1.7957
# time_step= 0
#
# vehicle_initial_state:
# position= [-87.702  243.7694]
# orientation= -2.4419
# velocity= 16.3085
# acceleration= 1.7957
# time_step= 0
#
# vehicle_initial_state.velocity:     16.3085
# vehicle_initial_state.position:     [-87.702  243.7694]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14ecd950>
# distance_sensor.vehicles_in_range:  [39, 311, 313, 315, 318]
# score_array:      {39: 15.072084910409572, 311: 15.072084910409572, 315: 33.58138330930538, 318: 39.0732469889311, 313: 39.07324698893112}
# group_array:      [39, 311, 315, 318, 313]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14ecdfd0>
# vehicle_info:     {'id': 39, 'initial_position': array([-130.5919,  198.8162]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c15769050>, 'initial_lanelet_id': 60, 'initial_lanelet_node': 5, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-130.5919  198.8162]
# orientation= -2.1871
# velocity= 23.4588
# acceleration= 0.5537
# time_step= 0
#
# vehicle_initial_state:
# position= [-130.5919  198.8162]
# orientation= -2.1871
# velocity= 23.4588
# acceleration= 0.5537
# time_step= 0
#
# vehicle_initial_state.velocity:     23.4588
# vehicle_initial_state.position:     [-130.5919  198.8162]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eef610>
# distance_sensor.vehicles_in_range:  [35, 311, 315]
# score_array:      {311: 5.0, 35: 15.072084910409572, 315: 33.58138330930538}
# group_array:      [35, 311, 315]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14ecdf50>
# vehicle_info:     {'id': 311, 'initial_position': array([-97.9548, 229.5944]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c1576a550>, 'initial_lanelet_id': 60, 'initial_lanelet_node': 0, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-97.9548 229.5944]
# orientation= -2.4968
# velocity= 25.4455
# acceleration= -0.6492
# time_step= 0
#
# vehicle_initial_state:
# position= [-97.9548 229.5944]
# orientation= -2.4968
# velocity= 25.4455
# acceleration= -0.6492
# time_step= 0
#
# vehicle_initial_state.velocity:     25.4455
# vehicle_initial_state.position:     [-97.9548 229.5944]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eef6d0>
# distance_sensor.vehicles_in_range:  [35, 39, 315]
# score_array:      {39: 5.0, 35: 15.072084910409572, 315: 33.58138330930538}
# group_array:      [35, 39, 315]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14ecd850>
# vehicle_info:     {'id': 313, 'initial_position': array([-22.8032, 297.0531]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c15775e10>, 'initial_lanelet_id': 62, 'initial_lanelet_node': 0, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-22.8032 297.0531]
# orientation= -2.4246
# velocity= 22.4416
# acceleration= 0.0902
# time_step= 0
#
# vehicle_initial_state:
# position= [-22.8032 297.0531]
# orientation= -2.4246
# velocity= 22.4416
# acceleration= 0.0902
# time_step= 0
#
# vehicle_initial_state.velocity:     22.4416
# vehicle_initial_state.position:     [-22.8032 297.0531]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eef750>
# distance_sensor.vehicles_in_range:  [35, 318]
# score_array:      {318: 5.000000000000011, 35: 39.07324698893112}
# group_array:      [35, 318]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eef5d0>
# vehicle_info:     {'id': 315, 'initial_position': array([-66.1657, 250.5458]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c15711cd0>, 'initial_lanelet_id': 63, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-66.1657 250.5458]
# orientation= -2.611
# velocity= 23.5856
# acceleration= 1.6903
# time_step= 0
#
# vehicle_initial_state:
# position= [-66.1657 250.5458]
# orientation= -2.611
# velocity= 23.5856
# acceleration= 1.6903
# time_step= 0
#
# vehicle_initial_state.velocity:     23.5856
# vehicle_initial_state.position:     [-66.1657 250.5458]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eef7d0>
# distance_sensor.vehicles_in_range:  [35, 39, 311, 317, 320]
# score_array:      {317: 9.625613207295132, 35: 33.58138330930538, 39: 33.58138330930538, 311: 33.58138330930538, 320: 37.07077003758829}
# group_array:      [35, 39, 311, 317, 320]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eef810>
# vehicle_info:     {'id': 317, 'initial_position': array([-34.8287, 267.4852]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c157437d0>, 'initial_lanelet_id': 64, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-34.8287 267.4852]
# orientation= -2.568
# velocity= 18.7462
# acceleration= -3.1206
# time_step= 0
#
# vehicle_initial_state:
# position= [-34.8287 267.4852]
# orientation= -2.568
# velocity= 18.7462
# acceleration= -3.1206
# time_step= 0
#
# vehicle_initial_state.velocity:     18.7462
# vehicle_initial_state.position:     [-34.8287 267.4852]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eef890>
# distance_sensor.vehicles_in_range:  [315, 320]
# score_array:      {315: 9.625613207295132, 320: 16.035949526547334}
# group_array:      [315, 320]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eef710>
# vehicle_info:     {'id': 318, 'initial_position': array([  8.049 , 324.4364]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c156df7d0>, 'initial_lanelet_id': 59, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [  8.049  324.4364]
# orientation= -2.4136
# velocity= 24.2938
# acceleration= -0.024
# time_step= 0
#
# vehicle_initial_state:
# position= [  8.049  324.4364]
# orientation= -2.4136
# velocity= 24.2938
# acceleration= -0.024
# time_step= 0
#
# vehicle_initial_state.velocity:     24.2938
# vehicle_initial_state.position:     [  8.049  324.4364]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eef910>
# distance_sensor.vehicles_in_range:  [-1, 35, 313, 321, 327, 328]
# score_array:      {-1: 5.0, 321: 5, 327: 5.0, 313: 5.000000000000011, 328: 28.78465348598317, 35: 39.0732469889311}
# group_array:      [-1, 35, 313, 321, 327, 328]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eef990>
# vehicle_info:     {'id': 319, 'initial_position': array([ 30.674 , 324.2206]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c15694690>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 13, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 30.674  324.2206]
# orientation= -2.4134
# velocity= 21.9676
# acceleration= -2.5321
# time_step= 0
#
# vehicle_initial_state:
# position= [ 30.674  324.2206]
# orientation= -2.4134
# velocity= 21.9676
# acceleration= -2.5321
# time_step= 0
#
# vehicle_initial_state.velocity:     21.9676
# vehicle_initial_state.position:     [ 30.674  324.2206]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eef950>
# distance_sensor.vehicles_in_range:  [320, 322, 323, 324, 326]
# score_array:      {320: 5, 322: 5, 323: 5, 324: 5, 326: 5}
# group_array:      [320, 322, 323, 324, 326]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eefa90>
# vehicle_info:     {'id': 320, 'initial_position': array([-10.5665, 284.8248]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c15652e10>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 16, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [-10.5665 284.8248]
# orientation= -2.4914
# velocity= 19.6346
# acceleration= -1.6412
# time_step= 0
#
# vehicle_initial_state:
# position= [-10.5665 284.8248]
# orientation= -2.4914
# velocity= 19.6346
# acceleration= -1.6412
# time_step= 0
#
# vehicle_initial_state.velocity:     19.6346
# vehicle_initial_state.position:     [-10.5665 284.8248]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eefa10>
# distance_sensor.vehicles_in_range:  [315, 317, 319, 322, 323, 324, 326]
# score_array:      {319: 5, 322: 5, 323: 5, 324: 5, 326: 5, 317: 16.035949526547334, 315: 37.07077003758829}
# group_array:      [315, 317, 319, 322, 323, 324, 326]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eefa50>
# vehicle_info:     {'id': 321, 'initial_position': array([ 39.1096, 352.1208]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c15619190>, 'initial_lanelet_id': 59, 'initial_lanelet_node': 1, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 39.1096 352.1208]
# orientation= -2.4137
# velocity= 25.36
# acceleration= 1.4723
# time_step= 0
#
# vehicle_initial_state:
# position= [ 39.1096 352.1208]
# orientation= -2.4137
# velocity= 25.36
# acceleration= 1.4723
# time_step= 0
#
# vehicle_initial_state.velocity:     25.36
# vehicle_initial_state.position:     [ 39.1096 352.1208]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eefb50>
# distance_sensor.vehicles_in_range:  [-1, 318, 327, 328]
# score_array:      {-1: 5.0, 318: 5, 327: 5.0, 328: 28.78465348598317}
# group_array:      [-1, 318, 327, 328]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eef790>
# vehicle_info:     {'id': 322, 'initial_position': array([ 18.23  , 308.4819]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c155dee10>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 13, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 18.23   308.4819]
# orientation= -2.4287
# velocity= 21.5555
# acceleration= -4.1209
# time_step= 0
#
# vehicle_initial_state:
# position= [ 18.23   308.4819]
# orientation= -2.4287
# velocity= 21.5555
# acceleration= -4.1209
# time_step= 0
#
# vehicle_initial_state.velocity:     21.5555
# vehicle_initial_state.position:     [ 18.23   308.4819]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eefbd0>
# distance_sensor.vehicles_in_range:  [319, 320, 323, 324, 326]
# score_array:      {319: 5, 320: 5, 323: 5, 324: 5, 326: 5}
# group_array:      [319, 320, 323, 324, 326]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14ecd710>
# vehicle_info:     {'id': 323, 'initial_position': array([ 59.0238, 349.2613]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c15567050>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 11, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 59.0238 349.2613]
# orientation= -2.4269
# velocity= 22.4868
# acceleration= 1.4001
# time_step= 0
#
# vehicle_initial_state:
# position= [ 59.0238 349.2613]
# orientation= -2.4269
# velocity= 22.4868
# acceleration= 1.4001
# time_step= 0
#
# vehicle_initial_state.velocity:     22.4868
# vehicle_initial_state.position:     [ 59.0238 349.2613]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eefc90>
# distance_sensor.vehicles_in_range:  [319, 320, 322, 324, 326]
# score_array:      {319: 5, 320: 5, 322: 5, 324: 5, 326: 5}
# group_array:      [319, 320, 322, 324, 326]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eefd50>
# vehicle_info:     {'id': 324, 'initial_position': array([ 47.963 , 334.9498]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c1557ecd0>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 12, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 47.963  334.9498]
# orientation= -2.4133
# velocity= 23.6817
# acceleration= -1.3191
# time_step= 0
#
# vehicle_initial_state:
# position= [ 47.963  334.9498]
# orientation= -2.4133
# velocity= 23.6817
# acceleration= -1.3191
# time_step= 0
#
# vehicle_initial_state.velocity:     23.6817
# vehicle_initial_state.position:     [ 47.963  334.9498]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eefcd0>
# distance_sensor.vehicles_in_range:  [319, 320, 322, 323, 326]
# score_array:      {319: 5, 320: 5, 322: 5, 323: 5, 326: 5}
# group_array:      [319, 320, 322, 323, 326]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eefe10>
# vehicle_info:     {'id': 326, 'initial_position': array([ 73.9127, 357.5201]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c154dccd0>, 'initial_lanelet_id': 57, 'initial_lanelet_node': 11, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 73.9127 357.5201]
# orientation= -2.4286
# velocity= 21.0765
# acceleration= 1.7579
# time_step= 0
#
# vehicle_initial_state:
# position= [ 73.9127 357.5201]
# orientation= -2.4286
# velocity= 21.0765
# acceleration= 1.7579
# time_step= 0
#
# vehicle_initial_state.velocity:     21.0765
# vehicle_initial_state.position:     [ 73.9127 357.5201]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eefd90>
# distance_sensor.vehicles_in_range:  [319, 320, 322, 323, 324]
# score_array:      {319: 5, 320: 5, 322: 5, 323: 5, 324: 5}
# group_array:      [319, 320, 322, 323, 324]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eefed0>
# vehicle_info:     {'id': 327, 'initial_position': array([ 94.6548, 401.6375]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c1546e050>, 'initial_lanelet_id': 65, 'initial_lanelet_node': 3, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [ 94.6548 401.6375]
# orientation= -2.4084
# velocity= 18.8144
# acceleration= 2.411
# time_step= 0
#
# vehicle_initial_state:
# position= [ 94.6548 401.6375]
# orientation= -2.4084
# velocity= 18.8144
# acceleration= 2.411
# time_step= 0
#
# vehicle_initial_state.velocity:     18.8144
# vehicle_initial_state.position:     [ 94.6548 401.6375]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eefe50>
# distance_sensor.vehicles_in_range:  [-1, 318, 321, 328, 329, 330]
# score_array:      {-1: 5.0, 318: 5.0, 321: 5.0, 328: 5.0000000000000036, 329: 39.34854985658056, 330: 39.34854985658056}
# group_array:      [-1, 318, 321, 328, 329, 330]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eeff50>
# vehicle_info:     {'id': 328, 'initial_position': array([114.5878, 421.2139]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c15408b90>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 2, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [114.5878 421.2139]
# orientation= -2.332
# velocity= 15.8235
# acceleration= 2.294
# time_step= 0
#
# vehicle_initial_state:
# position= [114.5878 421.2139]
# orientation= -2.332
# velocity= 15.8235
# acceleration= 2.294
# time_step= 0
#
# vehicle_initial_state.velocity:     15.8235
# vehicle_initial_state.position:     [114.5878 421.2139]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14eeff10>
# distance_sensor.vehicles_in_range:  [-1, 318, 321, 327, 329, 330, 331]
# score_array:      {329: 5, 330: 5, 331: 5.0, 327: 5.0000000000000036, -1: 28.78465348598317, 318: 28.78465348598317, 321: 28.78465348598317}
# group_array:      [-1, 318, 321, 327, 329, 330, 331]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14eeffd0>
# vehicle_info:     {'id': 329, 'initial_position': array([134.6273, 442.2464]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c153fb7d0>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 1, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [134.6273 442.2464]
# orientation= -2.3321
# velocity= 11.3675
# acceleration= 1.7994
# time_step= 0
#
# vehicle_initial_state:
# position= [134.6273 442.2464]
# orientation= -2.3321
# velocity= 11.3675
# acceleration= 1.7994
# time_step= 0
#
# vehicle_initial_state.velocity:     11.3675
# vehicle_initial_state.position:     [134.6273 442.2464]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14ef8050>
# distance_sensor.vehicles_in_range:  [327, 328, 330, 331]
# score_array:      {328: 5, 330: 5, 331: 5.0, 327: 39.34854985658056}
# group_array:      [327, 328, 330, 331]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14ef80d0>
# vehicle_info:     {'id': 330, 'initial_position': array([145.9309, 454.1039]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c15366410>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 1, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [145.9309 454.1039]
# orientation= -2.3323
# velocity= 8.2769
# acceleration= 1.5782
# time_step= 0
#
# vehicle_initial_state:
# position= [145.9309 454.1039]
# orientation= -2.3323
# velocity= 8.2769
# acceleration= 1.5782
# time_step= 0
#
# vehicle_initial_state.velocity:     8.2769
# vehicle_initial_state.position:     [145.9309 454.1039]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14ef8110>
# distance_sensor.vehicles_in_range:  [327, 328, 329, 331]
# score_array:      {328: 5, 329: 5, 331: 5.0, 327: 39.34854985658056}
# group_array:      [327, 328, 329, 331]
# knowledge_base:   None
# ___________________________________________________________________________________________________
# vehicle object:   <Vehicle.Vehicle object at 0x7f5c14ef8150>
# vehicle_info:     {'id': 331, 'initial_position': array([153.7147, 462.2688]), 'initial_state': <commonroad.scenario.trajectory.State object at 0x7f5c152a8050>, 'initial_lanelet_id': 53, 'initial_lanelet_node': 0, 'planning_problem_id': -1}
# **vehicle_info.initial_state:
# position= [153.7147 462.2688]
# orientation= -2.3323
# velocity= 5.2449
# acceleration= 1.3603
# time_step= 0
#
# vehicle_initial_state:
# position= [153.7147 462.2688]
# orientation= -2.3323
# velocity= 5.2449
# acceleration= 1.3603
# time_step= 0
#
# vehicle_initial_state.velocity:     5.2449
# vehicle_initial_state.position:     [153.7147 462.2688]
# vehicle_graph:    <GraphBasedDistanceMeasure.ScenarioGraph object at 0x7f5c44619410>
# distance_sensor:  <Sensor.DistanceSensor object at 0x7f5c14ef8190>
# distance_sensor.vehicles_in_range:  [328, 329, 330]
# score_array:      {328: 5.0, 329: 5.0, 330: 5.0}
# group_array:      [328, 329, 330]
# knowledge_base:   None
# ___________________________________________________________________________________________________

# %%
#find unique groups
from Visualization import VisualizationFunctions
visualization_function = VisualizationFunctions(SG_1)
print(visualization_function.vehicle_id_group_id)

for vehicle in SG_1.vehicle_objects_dict:
    print(vehicle, SG_1.vehicle_objects_dict[vehicle].group_array)
# Out:
# {-1: 1, 318: 11, 321: 17, 327: 24, 328: 26, 35: 3, 39: 5, 311: 6, 315: 6, 313: 7, 317: 8, 320: 15, 319: 8, 322: 20, 323: 22, 324: 23, 326: 23, 329: 28, 330: 29, 331: 29}
# -1 [318, 321, 327, 328]
# 35 [39, 311, 315, 318, 313]
# 39 [35, 311, 315]
# 311 [35, 39, 315]
# 313 [35, 318]
# 315 [35, 39, 311, 317, 320]
# 317 [315, 320]
# 318 [-1, 35, 313, 321, 327, 328]
# 319 [320, 322, 323, 324, 326]
# 320 [315, 317, 319, 322, 323, 324, 326]
# 321 [-1, 318, 327, 328]
# 322 [319, 320, 323, 324, 326]
# 323 [319, 320, 322, 324, 326]
# 324 [319, 320, 322, 323, 326]
# 326 [319, 320, 322, 323, 324]
# 327 [-1, 318, 321, 328, 329, 330]
# 328 [-1, 318, 321, 327, 329, 330, 331]
# 329 [327, 328, 330, 331]
# 330 [327, 328, 329, 331]
# 331 [328, 329, 330]

# %%
#best groups for each vehicle in the all groups
import numpy as np
all_groups = list()
for v_o in SG_1.vehicle_objects_dict:
    all_groups.append(SG_1.vehicle_objects_dict[v_o].group_array)
print(all_groups)
# Out:
# [[318, 321, 327, 328], [39, 311, 315, 318, 313], [35, 311, 315], [35, 39, 315], [35, 318], [35, 39, 311, 317, 320], [315, 320], [-1, 35, 313, 321, 327, 328], [320, 322, 323, 324, 326], [315, 317, 319, 322, 323, 324, 326], [-1, 318, 327, 328], [319, 320, 323, 324, 326], [319, 320, 322, 324, 326], [319, 320, 322, 323, 326], [319, 320, 322, 323, 324], [-1, 318, 321, 328, 329, 330], [-1, 318, 321, 327, 329, 330, 331], [327, 328, 330, 331], [327, 328, 329, 331], [328, 329, 330]]

# %%
print(visualization_function.group_id_vehicle_ids)
print(visualization_function.vehicle_id_group_id)
# Out:
# {1: [318, -1, 321, 327, 328], 2: [39, 35, 311, 315], 3: [318, 35, 313], 4: [311, 39], 5: [315, 39], 6: [315, 311, 317, 320], 7: [318, 313], 8: [320, 317, 319, 322, 323, 324, 326], 9: [321, 318], 10: [327, 318], 11: [328, 318], 12: [322, 320], 13: [323, 320], 14: [324, 320], 15: [326, 320], 16: [327, 321], 17: [328, 321], 18: [323, 322], 19: [324, 322], 20: [326, 322], 21: [324, 323], 22: [326, 323], 23: [326, 324], 24: [328, 327, 329, 330], 25: [329, 328], 26: [330, 328, 331], 27: [330, 329], 28: [331, 329], 29: [331, 330]}
# {-1: 1, 318: 11, 321: 17, 327: 24, 328: 26, 35: 3, 39: 5, 311: 6, 315: 6, 313: 7, 317: 8, 320: 15, 319: 8, 322: 20, 323: 22, 324: 23, 326: 23, 329: 28, 330: 29, 331: 29}

# %%
#take the groups results constracted after decisions of vehicles = gcbvd
#put them together in a list = all_groups
gcbvd = visualization_function.group_id_vehicle_ids
print(gcbvd)
all_groups = []
for k in gcbvd:
    all_groups.append(gcbvd[k])
    
print(all_groups)
# Out:
# {1: [318, -1, 321, 327, 328], 2: [39, 35, 311, 315], 3: [318, 35, 313], 4: [311, 39], 5: [315, 39], 6: [315, 311, 317, 320], 7: [318, 313], 8: [320, 317, 319, 322, 323, 324, 326], 9: [321, 318], 10: [327, 318], 11: [328, 318], 12: [322, 320], 13: [323, 320], 14: [324, 320], 15: [326, 320], 16: [327, 321], 17: [328, 321], 18: [323, 322], 19: [324, 322], 20: [326, 322], 21: [324, 323], 22: [326, 323], 23: [326, 324], 24: [328, 327, 329, 330], 25: [329, 328], 26: [330, 328, 331], 27: [330, 329], 28: [331, 329], 29: [331, 330]}
# [[318, -1, 321, 327, 328], [39, 35, 311, 315], [318, 35, 313], [311, 39], [315, 39], [315, 311, 317, 320], [318, 313], [320, 317, 319, 322, 323, 324, 326], [321, 318], [327, 318], [328, 318], [322, 320], [323, 320], [324, 320], [326, 320], [327, 321], [328, 321], [323, 322], [324, 322], [326, 322], [324, 323], [326, 323], [326, 324], [328, 327, 329, 330], [329, 328], [330, 328, 331], [330, 329], [331, 329], [331, 330]]

# %%
from Visualization import VisualizationFunctions
visualization_function = VisualizationFunctions(SG_1)
#print(visualization_function.group_ids)

import os
import matplotlib.pyplot as plt
from IPython import display
from brute_force import calculate_score
import commonroad.planning
# import functions to read xml file and visualize commonroad objects
from commonroad.common.file_reader import CommonRoadFileReader
from commonroad.visualization.draw_dispatch_cr import draw_object
import scenarios 
import matplotlib.patches as patches
from brute_force import Colorize_groups
import Convert_groups

groups=[]
# calculate_scores
grouparray= all_groups
print(all_groups)

for group in grouparray:
    groups.append(Convert_groups.conv_to_obj(scenario, planning_problem_set, group))

print(all_groups)
# plot the scenario for 40 time step, here each time step corresponds to 0.1 second
for i in range(0, 40):
    
    display.clear_output(wait=True)
    
    plt.figure(figsize=(20, 10))
    # plot the scenario at different time step   
    
    ax = plt.gca()
    
    draw_object(scenario.lanelet_network,draw_params={'time_begin': i}) #, plot_limits=plot_limits)
    time = i
    Colorize_groups.colorize_groups(groups, ax, time, visualization_function.vehicle_id_group_id)
    #raw_object(commonroad.planning.planning_problem.PlanningProblemSet.find_planning_problem_by_id(planning_problem_set, 2), draw_params=draw_params)
    #ect=patches.Rectangle((0,0),5,2,linewidth=1,edgecolor='#880000', facecolor='#998822')
    #x.add_patch(rect)
    # plot the planning problem set
    draw_object(planning_problem_set)
    plt.gca().set_aspect('equal')
    plt.show()
    break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-db645ff2decb> in <module>()
#      37     draw_object(scenario.lanelet_network,draw_params={'time_begin': i}) #, plot_limits=plot_limits)
#      38     time = i
# ---> 39     Colorize_groups.colorize_groups(groups, ax, time, visualization_function.group_id_vehicle_ids)
#      40     #raw_object(commonroad.planning.planning_problem.PlanningProblemSet.find_planning_problem_by_id(planning_problem_set, 2), draw_params=draw_params)
#      41     #ect=patches.Rectangle((0,0),5,2,linewidth=1,edgecolor='#880000', facecolor='#998822')
#
# /home/melike/Documents/TUM/20S/Praktikum/MyPraktikum/CCFCG/group-formation/brute_force/Colorize_groups.py in colorize_groups(group_assignment, axes, time, group_ids)
#      18             else:
#      19                 draw_params = draw_params = {  'time_begin': time,
# ---> 20                                                'dynamic_obstacle':{'shape':{'facecolor': colors[group_ids[veh.obstacle_id]]}}}
#      21                 draw_object(veh, draw_params=draw_params)
#      22
#
# KeyError: 318
